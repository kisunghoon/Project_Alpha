# %% [markdown]
# # Split - Apply - Combine strategy
#
# ![](https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&fname=https%3A%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F9978503F5B8264490F)

# %%
# '데이터' 관련 하여 어떠한 문제 해결에 있어서

# split - apply - combine  전략 사용.
# (분할 - 적용 - 병합)

#  'R; 에서도 이와 같이 구현되었는데  (
#      그룹으로 나누고 (split)
#      동일한 연산 수행후에 (apply)
#      결과를 합치는 과정 (combine)

# 원래 R 에서 구현하던 방식. 이걸 고안하신 분의 논문 "Strategy of Split-Apply-Combine" 에서 주창
# 꽤 많은 문제들이 Split-Apply-Combine 으로 '문제해결' 을 할수 있슴을 주장

# 엑셀등에서도 많이 하는 작업

# 가령 
#     ex) '일별'로 묶어서 일별 매출 구하기
#     ex) '상품 카테고리별'로 묶어서 상품이 특정 기간의 매출 구하기
#     ex) '유저' 별 매출


# 여기서 복잡해 지는 상황은 바로 'apply' 과정입니다

# apply 과정
#    - aggregate() agg() : N => 1    집계하는 연산, 'N개를 입력' 받아서 '1개의 결과'를 만들어 내기    ex)합계
#    - transform() : N => N'       'N개를 입력'받아서  '전체' 를 바꿈
#    - apply() : N => 1, N, M...   'N개를 입력'받아서  '1개' 'N개' 혹은 'M개' 의 결과 를 만들어 냄.
#    - filter() : N => N보다 같거나 적은 


# ※ 나중에 보면, apply() 만으로도 모~든 것들이 가능해짐을 알게 된다.

# %%
import pandas as pd
import numpy as np

# %%
filepath = r"D:\DevRoot\DataSet\mysql\world\country.csv"

# %%
df = pd.read_csv(filepath)
df
# Out:
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# 235  YUG    Yugoslavia         Europe            Southern Europe     102173.0
# 236  ZAF  South Africa         Africa            Southern Africa    1221037.0
# 237  ZMB        Zambia         Africa             Eastern Africa     752618.0
# 238  ZWE      Zimbabwe         Africa             Eastern Africa     390757.0
#
#      IndepYear  Population  LifeExpectancy       GNP    GNPOld  \
# 0          NaN      103000            78.4     828.0     793.0
# 1       1919.0    22720000            45.9    5976.0       NaN
# 2       1975.0    12878000            38.3    6648.0    7984.0
# 3          NaN        8000            76.1      63.2       NaN
# 4       1912.0     3401200            71.6    3205.0    2500.0
# ..         ...         ...             ...       ...       ...
# 234     1918.0    18112000            59.8    6041.0    5729.0
# 235     1918.0    10640000            72.4   17000.0       NaN
# 236     1910.0    40377000            51.1  116729.0  129092.0
# 237     1964.0     9169000            37.2    3377.0    3922.0
# 238     1980.0    11669000            37.8    5951.0    8670.0
#
#                  LocalName                                GovernmentForm  \
# 0                    Aruba  Nonmetropolitan Territory of The Netherlands
# 1    Afganistan/Afqanestan                               Islamic Emirate
# 2                   Angola                                      Republic
# 3                 Anguilla                 Dependent Territory of the UK
# 4               ShqipÃ«ria                                      Republic
# ..                     ...                                           ...
# 234               Al-Yaman                                      Republic
# 235            Jugoslavija                              Federal Republic
# 236           South Africa                                      Republic
# 237                 Zambia                                      Republic
# 238               Zimbabwe                                      Republic
#
#                   HeadOfState  Capital Code2
# 0                     Beatrix    129.0    AW
# 1               Mohammad Omar      1.0    AF
# 2    JosÃ© Eduardo dos Santos     56.0    AO
# 3                Elisabeth II     62.0    AI
# 4              Rexhep Mejdani     34.0    AL
# ..                        ...      ...   ...
# 234        Ali Abdallah Salih   1780.0    YE
# 235       Vojislav KoÂštunica   1792.0    YU
# 236               Thabo Mbeki    716.0    ZA
# 237         Frederick Chiluba   3162.0    ZM
# 238          Robert G. Mugabe   4068.0    ZW
#
# [239 rows x 15 columns]

# %% [markdown]
# ## aggregate(집계) 함수 사용하기
#  - groupby 결과에 '집계함수'를 적용하여 그룹별 데이터 확인 가능
#  - ex) sum(), count(), mean(), max() ...

# %%
df.mean() # '수치타입' 모든 컬럼에 대한 평균
# Out:
# SurfaceArea       6.232481e+05
# IndepYear         1.847260e+03
# Population        2.543410e+07
# LifeExpectancy    6.648604e+01
# GNP               1.228239e+05
# GNPOld            1.655343e+05
# Capital           2.071306e+03
# dtype: float64

# %%
df.sum()
# Out:
# Code              ABWAFGAGOAIAALBANDANTAREARGARMASMATAATFATGAUSA...
# Name              ArubaAfghanistanAngolaAnguillaAlbaniaAndorraNe...
# Continent         North AmericaAsiaAfricaNorth AmericaEuropeEuro...
# Region            CaribbeanSouthern and Central AsiaCentral Afri...
# SurfaceArea                                             1.48956e+08
# IndepYear                                                    354674
# Population                                               6078749450
# LifeExpectancy                                              14759.9
# GNP                                                     2.93549e+07
# GNPOld                                                  2.94651e+07
# LocalName         ArubaAfganistan/AfqanestanAngolaAnguillaShqipÃ...
# GovernmentForm    Nonmetropolitan Territory of The NetherlandsIs...
# Capital                                                      480543
# dtype: object

# %% [markdown]
# ### 대륙별 grouping
# split!

# %%
df['Continent']
# Out:
# 0      North America
# 1               Asia
# 2             Africa
# 3      North America
# 4             Europe
#            ...
# 234             Asia
# 235           Europe
# 236           Africa
# 237           Africa
# 238           Africa
# Name: Continent, Length: 239, dtype: object

# %%
df.Continent
# Out:
# 0      North America
# 1               Asia
# 2             Africa
# 3      North America
# 4             Europe
#            ...
# 234             Asia
# 235           Europe
# 236           Africa
# 237           Africa
# 238           Africa
# Name: Continent, Length: 239, dtype: object

# %%
# 대륙은 총 몇가지가 있나?
df.Continent.unique()  # 7개
# Out:
# array(['North America', 'Asia', 'Africa', 'Europe', 'South America',
#        'Oceania', 'Antarctica'], dtype=object)

# %%
# 대륙별로 쪼개기 (grouping) --> split!
gc = df.groupby("Continent")
gc.size()
# Out:
# Continent
# Africa           58
# Antarctica        5
# Asia             51
# Europe           46
# North America    37
# Oceania          28
# South America    14
# dtype: int64

# %%
gc = df.groupby(df.Continent)
gc.size()
# Out:
# Continent
# Africa           58
# Antarctica        5
# Asia             51
# Europe           46
# North America    37
# Oceania          28
# South America    14
# dtype: int64

# %%
len(gc)
# Out:
# 7

# %%
gc.groups # dict  그룹명: [index ...]
# Out:
# {'Africa': [2, 17, 19, 20, 35, 36, 42, 43, 44, 45, 48, 49, 57, 61, 63, 64, 65, 68, 75, 78, 80, 82, 83, 84, 100, 111, 120, 121, 125, 130, 133, 138, 143, 144, 147, 148, 150, 151, 153, 155, 179, 182, 184, 185, 188, 191, 194, 196, 201, 202, 205, 206, 214, 218, 219, 236, 237, 238], 'Antarctica': [11, 12, 34, 93, 187], 'Asia': [1, 7, 9, 16, 21, 23, 32, 33, 41, 54, 77, 92, 98, 99, 102, 103, 105, 108, 109, 110, 112, 113, 116, 117, 118, 119, 124, 129, 134, 140, 141, 149, 160, 163, 164, 168, 173, 176, 178, 183, 186, 203, 207, 208, 210, 211, 215, 217, 224, 230, 234], 'Europe': [4, 5, 15, 18, 22, 25, 26, 39, 55, 56, 59, 66, 67, 69, 72, 73, 76, 79, 85, 95, 97, 101, 104, 106, 123, 126, 127, 128, 131, 132, 137, 139, 158, 159, 171, 174, 180, 181, 189, 193, 198, 199, 200, 220, 225, 235], 'North America': [0, 3, 6, 13, 24, 27, 28, 31, 37, 50, 51, 53, 58, 60, 81, 86, 87, 88, 94, 96, 107, 115, 122, 135, 145, 146, 156, 165, 172, 192, 195, 204, 213, 223, 226, 228, 229], 'Oceania': [10, 14, 38, 46, 52, 70, 74, 90, 114, 136, 142, 152, 154, 157, 161, 162, 166, 169, 170, 177, 190, 209, 212, 216, 221, 231, 232, 233], 'South America': [8, 29, 30, 40, 47, 62, 71, 89, 91, 167, 175, 197, 222, 227]}

# %%
gc.get_group('Asia').head()
# Out:
#    Code                  Name Continent                     Region  \
# 1   AFG           Afghanistan      Asia  Southern and Central Asia
# 7   ARE  United Arab Emirates      Asia                Middle East
# 9   ARM               Armenia      Asia                Middle East
# 16  AZE            Azerbaijan      Asia                Middle East
# 21  BGD            Bangladesh      Asia  Southern and Central Asia
#
#     SurfaceArea  IndepYear  Population  LifeExpectancy      GNP   GNPOld  \
# 1      652090.0     1919.0    22720000            45.9   5976.0      NaN
# 7       83600.0     1971.0     2441000            74.1  37966.0  36846.0
# 9       29800.0     1991.0     3520000            66.4   1813.0   1627.0
# 16      86600.0     1991.0     7734000            62.9   4127.0   4100.0
# 21     143998.0     1971.0   129155000            60.2  32852.0  31966.0
#
#                               LocalName      GovernmentForm  \
# 1                 Afganistan/Afqanestan     Islamic Emirate
# 7   Al-Imarat al-Â´Arabiya al-Muttahida  Emirate Federation
# 9                              Hajastan            Republic
# 16                          AzÃ¤rbaycan    Federal Republic
# 21                           Bangladesh            Republic
#
#                     HeadOfState  Capital Code2
# 1                 Mohammad Omar      1.0    AF
# 7   Zayid bin Sultan al-Nahayan     65.0    AE
# 9             Robert KotÂšarjan    126.0    AM
# 16              HeydÃ¤r Ã„liyev    144.0    AZ
# 21            Shahabuddin Ahmad    150.0    BD

# %%
gc.get_group("Europe").head()
# Out:
#    Code      Name Continent           Region  SurfaceArea  IndepYear  \
# 4   ALB   Albania    Europe  Southern Europe      28748.0     1912.0
# 5   AND   Andorra    Europe  Southern Europe        468.0     1278.0
# 15  AUT   Austria    Europe   Western Europe      83859.0     1918.0
# 18  BEL   Belgium    Europe   Western Europe      30518.0     1830.0
# 22  BGR  Bulgaria    Europe   Eastern Europe     110994.0     1908.0
#
#     Population  LifeExpectancy       GNP    GNPOld         LocalName  \
# 4      3401200            71.6    3205.0    2500.0        ShqipÃ«ria
# 5        78000            83.5    1630.0       NaN           Andorra
# 15     8091800            77.7  211860.0  206025.0       Ã–sterreich
# 18    10239000            77.8  249704.0  243948.0  BelgiÃ«/Belgique
# 22     8190900            70.9   12178.0   10169.0         Balgarija
#
#                          GovernmentForm     HeadOfState  Capital Code2
# 4                              Republic  Rexhep Mejdani     34.0    AL
# 5          Parliamentary Coprincipality             NaN     55.0    AD
# 15                     Federal Republic  Thomas Klestil   1523.0    AT
# 18  Constitutional Monarchy, Federation       Albert II    179.0    BE
# 22                             Republic  Petar Stojanov    539.0    BG

# %% [markdown]
# #### groupby 객체 도 iterable 하다

# %%
for group in gc:
    # 위에서 group 은 tuple 이 나온다 이다.
    # 위 tuple 은 두개의 값으로 이루어져 있다. 
    # [0] : group 이름
    # [1] : group 데이터 : DataFrame
    print(group[0])
# Out:
# Africa
# Antarctica
# Asia
# Europe
# North America
# Oceania
# South America

# %%
for groupid, group_df in gc:
    print(groupid)
# Out:
# Africa
# Antarctica
# Asia
# Europe
# North America
# Oceania
# South America

# %% [markdown]
# ## 대륙 x 지역별 그룹핑
# 복잡한 그룹핑

# %%
df.groupby(['Continent', 'Region']).size()
# Out:
# Continent      Region
# Africa         Central Africa                9
#                Eastern Africa               20
#                Northern Africa               7
#                Southern Africa               5
#                Western Africa               17
# Antarctica     Antarctica                    5
# Asia           Eastern Asia                  8
#                Middle East                  18
#                Southeast Asia               11
#                Southern and Central Asia    14
# Europe         Baltic Countries              3
#                British Islands               2
#                Eastern Europe               10
#                Nordic Countries              7
#                Southern Europe              15
#                Western Europe                9
# North America  Caribbean                    24
#                Central America               8
#                North America                 5
# Oceania        Australia and New Zealand     5
#                Melanesia                     5
#                Micronesia                    7
#                Micronesia/Caribbean          1
#                Polynesia                    10
# South America  South America                14
# dtype: int64

# %%
for group_name, group_df in df.groupby(['Continent', 'Region']):
    print(group_name)
    print(group_df.shape)
# Out:
# ('Africa', 'Central Africa')
# (9, 15)
# ('Africa', 'Eastern Africa')
# (20, 15)
# ('Africa', 'Northern Africa')
# (7, 15)
# ('Africa', 'Southern Africa')
# (5, 15)
# ('Africa', 'Western Africa')
# (17, 15)
# ('Antarctica', 'Antarctica')
# (5, 15)
# ('Asia', 'Eastern Asia')
# (8, 15)
# ('Asia', 'Middle East')
# (18, 15)
# ('Asia', 'Southeast Asia')
# (11, 15)
# ('Asia', 'Southern and Central Asia')
# (14, 15)
# ('Europe', 'Baltic Countries')
# (3, 15)
# ('Europe', 'British Islands')
# (2, 15)
# ('Europe', 'Eastern Europe')
# (10, 15)
# ('Europe', 'Nordic Countries')
# (7, 15)
# ('Europe', 'Southern Europe')
# (15, 15)
# ('Europe', 'Western Europe')
# (9, 15)
# ('North America', 'Caribbean')
# (24, 15)
# ('North America', 'Central America')
# (8, 15)
# ('North America', 'North America')
# (5, 15)
# ('Oceania', 'Australia and New Zealand')
# (5, 15)
# ('Oceania', 'Melanesia')
# (5, 15)
# ('Oceania', 'Micronesia')
# (7, 15)
# ('Oceania', 'Micronesia/Caribbean')
# (1, 15)
# ('Oceania', 'Polynesia')
# (10, 15)
# ('South America', 'South America')
# (14, 15)

# %% [markdown]
# ### GroupBy 에 적용 가능한 집계함수(aggregate func)들
# sum(), count(), mean() 등 적용 가능
#
# - 이 과정 또한 split-apply-combine

# %%
gc.mean()
# Out:
#                 SurfaceArea    IndepYear    Population  LifeExpectancy  \
# Continent
# Africa         5.215582e+05  1904.905660  1.352543e+07       52.571930
# Antarctica     2.626420e+06          NaN  0.000000e+00             NaN
# Asia           6.251177e+05  1808.531915  7.264756e+07       67.441176
# Europe         5.010681e+05  1750.488372  1.587119e+07       75.147727
# North America  6.544451e+05  1903.608696  1.305386e+07       72.991892
# Oceania        3.058676e+05  1967.285714  1.085755e+06       69.715000
# South America  1.276066e+06  1843.083333  2.469857e+07       70.946154
#
#                          GNP         GNPOld      Capital
# Continent
# Africa          10006.465517   11065.280000  2162.368421
# Antarctica          0.000000            NaN          NaN
# Asia           150105.725490  183377.088889  2038.803922
# Europe         206497.065217  260611.138889  2223.782609
# North America  261854.789189  371527.000000  1592.810811
# Oceania         14991.953571   46905.800000  2498.074074
# South America  107991.000000  126720.083333  1759.500000

# %%
gc.count()
# Out:
#                Code  Name  Region  SurfaceArea  IndepYear  Population  \
# Continent
# Africa           58    58      58           58         53          58
# Antarctica        5     5       5            5          0           5
# Asia             51    51      51           51         47          51
# Europe           46    46      46           46         43          46
# North America    37    37      37           37         23          37
# Oceania          28    28      28           28         14          28
# South America    14    14      14           14         12          14
#
#                LifeExpectancy  GNP  GNPOld  LocalName  GovernmentForm  \
# Continent
# Africa                     57   58      50         58              58
# Antarctica                  0    5       0          5               5
# Asia                       51   51      45         51              51
# Europe                     44   46      36         46              46
# North America              37   37      25         37              37
# Oceania                    20   28      10         28              28
# South America              13   14      12         14              14
#
#                HeadOfState  Capital  Code2
# Continent
# Africa                  58       57     57
# Antarctica               4        0      5
# Asia                    51       51     51
# Europe                  44       46     46
# North America           37       37     37
# Oceania                 28       27     28
# South America           14       14     14

# %%
gc.sum()
# Out:
#                SurfaceArea  IndepYear  Population  LifeExpectancy        GNP  \
# Continent
# Africa          30250377.0   100960.0   784475000          2996.6   580375.0
# Antarctica      13132101.0        0.0           0             0.0        0.0
# Asia            31881005.0    85001.0  3705025700          3439.5  7655392.0
# Europe          23049133.9    75271.0   730074600          3306.5  9498865.0
# North America   24214470.0    43783.0   482993000          2700.7  9688627.2
# Oceania          8564294.0    27542.0    30401150          1394.3   419774.7
# South America   17864926.0    22117.0   345780000           922.3  1511874.0
#
#                   GNPOld   Capital
# Continent
# Africa          553264.0  123255.0
# Antarctica           0.0       0.0
# Asia           8251969.0  103979.0
# Europe         9382001.0  102294.0
# North America  9288175.0   58934.0
# Oceania         469058.0   67448.0
# South America  1520641.0   24633.0

# %%
gc.std()
# Out:
#                 SurfaceArea   IndepYear    Population  LifeExpectancy  \
# Continent
# Africa         6.288632e+05  407.199217  2.007192e+07       10.751939
# Antarctica     5.866090e+06         NaN  0.000000e+00             NaN
# Asia           1.466192e+06  631.614937  2.248504e+08        8.396527
# Europe         2.503180e+06  370.226917  2.777396e+07        4.484884
# North America  2.235040e+06   74.378479  4.786430e+07        5.536263
# Oceania        1.460543e+06   28.290875  3.665679e+06        5.974091
# South America  2.217233e+06   59.865696  4.412130e+07        4.688393
#
#                         GNP        GNPOld      Capital
# Continent
# Africa         2.143651e+04  2.299791e+04  1089.668620
# Antarctica     0.000000e+00           NaN          NaN
# Asia           5.431181e+05  6.327974e+05  1133.096342
# Europe         4.409290e+05  4.739883e+05  1169.124761
# North America  1.398694e+06  1.618781e+06  1297.572538
# Oceania        6.668518e+04  1.232180e+05  1070.362840
# South America  2.122843e+05  2.312477e+05  1385.014954

# %% [markdown]
# ## 대륙별 면적 평균

# %%
df.groupby('Continent').mean()[['SurfaceArea']]

# split : Continent 별로 쪼개어짐
# apply : 쪼개어진 group 별로 평균(mean) 집계합수 적용
# combine : 하나의 DataFrame 으로 합계
# Out:
#                 SurfaceArea
# Continent
# Africa         5.215582e+05
# Antarctica     2.626420e+06
# Asia           6.251177e+05
# Europe         5.010681e+05
# North America  6.544451e+05
# Oceania        3.058676e+05
# South America  1.276066e+06

# %% [markdown]
# ## 대륙별 인구수 합계 (방법1)
# - 집계함수 사용
# - 인구수 내림차순 정렬

# %%
gc

# %%
aaa = gc.sum()[['Population']].sort_values(['Population'], ascending=False)
aaa
# Out:
#                Population
# Continent
# Asia           3705025700
# Africa          784475000
# Europe          730074600
# North America   482993000
# South America   345780000
# Oceania          30401150
# Antarctica              0

# %% [markdown]
# ### 대륙별 국가수 x 인구총수
# - 컬럼명을 '국가수' 로 바꾸기

# %%
ddd = gc.count()[['Name']]
ddd.columns = ['국가수']
ddd
# Out:
#                국가수
# Continent
# Africa          58
# Antarctica       5
# Asia            51
# Europe          46
# North America   37
# Oceania         28
# South America   14

# %%
df_merge = pd.merge(aaa, ddd, on="Continent")
df_merge
# Out:
#                Population  국가수
# Continent
# Asia           3705025700   51
# Africa          784475000   58
# Europe          730074600   46
# North America   482993000   37
# South America   345780000   14
# Oceania          30401150   28
# Antarctica              0    5

# %% [markdown]
# ## 대륙별 인구수 합계 (방법2)
# - agg() + 집계함수 사용

# %%
# groupby 객체에 agg() 적용하면 간단하게 결과 나옴!

# %%
gc.agg({"Population": "sum"})

# 이 또한 split-apply-combine
# Out:
#                Population
# Continent
# Africa          784475000
# Antarctica              0
# Asia           3705025700
# Europe          730074600
# North America   482993000
# Oceania          30401150
# South America   345780000

# %%
gc.agg({"Population": np.sum})
# Out:
#                Population
# Continent
# Africa          784475000
# Antarctica              0
# Asia           3705025700
# Europe          730074600
# North America   482993000
# Oceania          30401150
# South America   345780000

# %%
gc.aggregate({"Population": np.sum})
# Out:
#                Population
# Continent
# Africa          784475000
# Antarctica              0
# Asia           3705025700
# Europe          730074600
# North America   482993000
# Oceania          30401150
# South America   345780000

# %%
# agg() 를 하나의 컬럼에 여러 집계함수 사용 가능!
gc.agg({"Population" : ["sum", "mean"]})

# 결과는 multi column
# Out:
#                Population
#                       sum          mean
# Continent
# Africa          784475000  1.352543e+07
# Antarctica              0  0.000000e+00
# Asia           3705025700  7.264756e+07
# Europe          730074600  1.587119e+07
# North America   482993000  1.305386e+07
# Oceania          30401150  1.085755e+06
# South America   345780000  2.469857e+07

# %%
gc.agg({"Population" : [np.sum, np.mean]})
# Out:
#                Population
#                       sum          mean
# Continent
# Africa          784475000  1.352543e+07
# Antarctica              0  0.000000e+00
# Asia           3705025700  7.264756e+07
# Europe          730074600  1.587119e+07
# North America   482993000  1.305386e+07
# Oceania          30401150  1.085755e+06
# South America   345780000  2.469857e+07

# %%
# groupby(...) <-- 여기세는 함수, 리스트 등 여러가지 형태가 들어갈수 있다.

# %%
# 그러나
# 쇼핑몰 일별 매출 같은 것을 하면 위와 같은 groupby() 로는 힘들다
# 왜냐하면

# 타임스탬프가 아래와 같이 찍혀 있을테니..

# 2017-06-24-12:22:00:00
# 2017-06-24-12:22:00:00
# 2017-06-24-12:22:00:05
# 2017-06-24-12:22:00:04
# 2017-06-24-12:22:00:03
# 2017-06-24-12:22:00:02
# 2017-06-24-12:22:00:01

# 일별 집계를 하려면,  앞의 년-월-일 만 으로 그룹한다든지 해야 한다

# %% [markdown]
# # 각각의 알파벳으로 시작하는 국가들은 얼마나 될까?

# %%
# 각각의 알파벳으로 시작하는 국가들이 얼마나 될까?
# a ... 100
# b ... ?
# c ... ?

# %%
df.Name
# Out:
# 0             Aruba
# 1       Afghanistan
# 2            Angola
# 3          Anguilla
# 4           Albania
#            ...
# 234           Yemen
# 235      Yugoslavia
# 236    South Africa
# 237          Zambia
# 238        Zimbabwe
# Name: Name, Length: 239, dtype: object

# %%
# Series.apply() ==> map() 함수와 유사

# %%
#df.Name.apply(함수)
df.Name.apply(lambda name : name[0])
# Out:
# 0      A
# 1      A
# 2      A
# 3      A
# 4      A
#       ..
# 234    Y
# 235    Y
# 236    S
# 237    Z
# 238    Z
# Name: Name, Length: 239, dtype: object

# %%
# groupby() 매개변수로 Series!
# 다른 연산을 거친 Series 결과를 groupby() 에 넘겨주어, 다양한 그룹핑 가능

grouped = df.groupby(df.Name.apply(lambda name : name[0]))

grouped.size()
# Out:
# Name
# A    15
# B    20
# C    22
# D     4
# E     8
# F     8
# G    15
# H     6
# I     8
# J     3
# K     5
# L     9
# M    22
# N    15
# O     1
# P    12
# Q     1
# R     4
# S    29
# T    13
# U     8
# V     5
# W     2
# Y     2
# Z     2
# dtype: int64

# %%
# "A" 로 시작하는 국가들
grouped.get_group("A").head()
# Out:
#   Code         Name      Continent                     Region  SurfaceArea  \
# 0  ABW        Aruba  North America                  Caribbean        193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia     652090.0
# 2  AGO       Angola         Africa             Central Africa    1246700.0
# 3  AIA     Anguilla  North America                  Caribbean         96.0
# 4  ALB      Albania         Europe            Southern Europe      28748.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0        NaN      103000            78.4   828.0   793.0
# 1     1919.0    22720000            45.9  5976.0     NaN
# 2     1975.0    12878000            38.3  6648.0  7984.0
# 3        NaN        8000            76.1    63.2     NaN
# 4     1912.0     3401200            71.6  3205.0  2500.0
#
#                LocalName                                GovernmentForm  \
# 0                  Aruba  Nonmetropolitan Territory of The Netherlands
# 1  Afganistan/Afqanestan                               Islamic Emirate
# 2                 Angola                                      Republic
# 3               Anguilla                 Dependent Territory of the UK
# 4             ShqipÃ«ria                                      Republic
#
#                 HeadOfState  Capital Code2
# 0                   Beatrix    129.0    AW
# 1             Mohammad Omar      1.0    AF
# 2  JosÃ© Eduardo dos Santos     56.0    AO
# 3              Elisabeth II     62.0    AI
# 4            Rexhep Mejdani     34.0    AL

# %%
#groupby() 에 column 이름을 넣기도 하지만,
#대부분의 경우는 '추가적인 연산'을 수행해서  이 연산된 결과를 바탕으로 해서 하는 경우가 많습니다.
#(즉, 위와 같이 어떤 알파벳으로 시작하는지에 대한 연산)

# %% [markdown]
# # 대륙별 인구가 가장 많은 국가 1개씩

# %%
gc.size()
# Out:
# Continent
# Africa           58
# Antarctica        5
# Asia             51
# Europe           46
# North America    37
# Oceania          28
# South America    14
# dtype: int64

# %%
df.head()
# Out:
#   Code         Name      Continent                     Region  SurfaceArea  \
# 0  ABW        Aruba  North America                  Caribbean        193.0
# 1  AFG  Afghanistan           Asia  Southern and Central Asia     652090.0
# 2  AGO       Angola         Africa             Central Africa    1246700.0
# 3  AIA     Anguilla  North America                  Caribbean         96.0
# 4  ALB      Albania         Europe            Southern Europe      28748.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0        NaN      103000            78.4   828.0   793.0
# 1     1919.0    22720000            45.9  5976.0     NaN
# 2     1975.0    12878000            38.3  6648.0  7984.0
# 3        NaN        8000            76.1    63.2     NaN
# 4     1912.0     3401200            71.6  3205.0  2500.0
#
#                LocalName                                GovernmentForm  \
# 0                  Aruba  Nonmetropolitan Territory of The Netherlands
# 1  Afganistan/Afqanestan                               Islamic Emirate
# 2                 Angola                                      Republic
# 3               Anguilla                 Dependent Territory of the UK
# 4             ShqipÃ«ria                                      Republic
#
#                 HeadOfState  Capital Code2
# 0                   Beatrix    129.0    AW
# 1             Mohammad Omar      1.0    AF
# 2  JosÃ© Eduardo dos Santos     56.0    AO
# 3              Elisabeth II     62.0    AI
# 4            Rexhep Mejdani     34.0    AL

# %%
# 원래 DataFrame.head() 는 위에 있는 5개 row 를 보여주나,  
# GroupBy.head() 를 사용하면, 각각의 그룹에서 위에 있는 5개씩 뽑습니다.
gc.head()
# Out:
#     Code                                          Name      Continent  \
# 0    ABW                                         Aruba  North America
# 1    AFG                                   Afghanistan           Asia
# 2    AGO                                        Angola         Africa
# 3    AIA                                      Anguilla  North America
# 4    ALB                                       Albania         Europe
# 5    AND                                       Andorra         Europe
# 6    ANT                          Netherlands Antilles  North America
# 7    ARE                          United Arab Emirates           Asia
# 8    ARG                                     Argentina  South America
# 9    ARM                                       Armenia           Asia
# 10   ASM                                American Samoa        Oceania
# 11   ATA                                    Antarctica     Antarctica
# 12   ATF                   French Southern territories     Antarctica
# 13   ATG                           Antigua and Barbuda  North America
# 14   AUS                                     Australia        Oceania
# 15   AUT                                       Austria         Europe
# 16   AZE                                    Azerbaijan           Asia
# 17   BDI                                       Burundi         Africa
# 18   BEL                                       Belgium         Europe
# 19   BEN                                         Benin         Africa
# 20   BFA                                  Burkina Faso         Africa
# 21   BGD                                    Bangladesh           Asia
# 22   BGR                                      Bulgaria         Europe
# 24   BHS                                       Bahamas  North America
# 29   BOL                                       Bolivia  South America
# 30   BRA                                        Brazil  South America
# 34   BVT                                 Bouvet Island     Antarctica
# 35   BWA                                      Botswana         Africa
# 38   CCK                       Cocos (Keeling) Islands        Oceania
# 40   CHL                                         Chile  South America
# 46   COK                                  Cook Islands        Oceania
# 47   COL                                      Colombia  South America
# 52   CXR                              Christmas Island        Oceania
# 93   HMD             Heard Island and McDonald Islands     Antarctica
# 187  SGS  South Georgia and the South Sandwich Islands     Antarctica
#
#                         Region  SurfaceArea  IndepYear  Population  \
# 0                    Caribbean        193.0        NaN      103000
# 1    Southern and Central Asia     652090.0     1919.0    22720000
# 2               Central Africa    1246700.0     1975.0    12878000
# 3                    Caribbean         96.0        NaN        8000
# 4              Southern Europe      28748.0     1912.0     3401200
# 5              Southern Europe        468.0     1278.0       78000
# 6                    Caribbean        800.0        NaN      217000
# 7                  Middle East      83600.0     1971.0     2441000
# 8                South America    2780400.0     1816.0    37032000
# 9                  Middle East      29800.0     1991.0     3520000
# 10                   Polynesia        199.0        NaN       68000
# 11                  Antarctica   13120000.0        NaN           0
# 12                  Antarctica       7780.0        NaN           0
# 13                   Caribbean        442.0     1981.0       68000
# 14   Australia and New Zealand    7741220.0     1901.0    18886000
# 15              Western Europe      83859.0     1918.0     8091800
# 16                 Middle East      86600.0     1991.0     7734000
# 17              Eastern Africa      27834.0     1962.0     6695000
# 18              Western Europe      30518.0     1830.0    10239000
# 19              Western Africa     112622.0     1960.0     6097000
# 20              Western Africa     274000.0     1960.0    11937000
# 21   Southern and Central Asia     143998.0     1971.0   129155000
# 22              Eastern Europe     110994.0     1908.0     8190900
# 24                   Caribbean      13878.0     1973.0      307000
# 29               South America    1098581.0     1825.0     8329000
# 30               South America    8547403.0     1822.0   170115000
# 34                  Antarctica         59.0        NaN           0
# 35             Southern Africa     581730.0     1966.0     1622000
# 38   Australia and New Zealand         14.0        NaN         600
# 40               South America     756626.0     1810.0    15211000
# 46                   Polynesia        236.0        NaN       20000
# 47               South America    1138914.0     1810.0    42321000
# 52   Australia and New Zealand        135.0        NaN        2500
# 93                  Antarctica        359.0        NaN           0
# 187                 Antarctica       3903.0        NaN           0
#
#      LifeExpectancy       GNP    GNPOld  \
# 0              78.4     828.0     793.0
# 1              45.9    5976.0       NaN
# 2              38.3    6648.0    7984.0
# 3              76.1      63.2       NaN
# 4              71.6    3205.0    2500.0
# 5              83.5    1630.0       NaN
# 6              74.7    1941.0       NaN
# 7              74.1   37966.0   36846.0
# 8              75.1  340238.0  323310.0
# 9              66.4    1813.0    1627.0
# 10             75.1     334.0       NaN
# 11              NaN       0.0       NaN
# 12              NaN       0.0       NaN
# 13             70.5     612.0     584.0
# 14             79.8  351182.0  392911.0
# 15             77.7  211860.0  206025.0
# 16             62.9    4127.0    4100.0
# 17             46.2     903.0     982.0
# 18             77.8  249704.0  243948.0
# 19             50.2    2357.0    2141.0
# 20             46.7    2425.0    2201.0
# 21             60.2   32852.0   31966.0
# 22             70.9   12178.0   10169.0
# 24             71.1    3527.0    3347.0
# 29             63.7    8571.0    7967.0
# 30             62.9  776739.0  804108.0
# 34              NaN       0.0       NaN
# 35             39.3    4834.0    4935.0
# 38              NaN       0.0       NaN
# 40             75.7   72949.0   75780.0
# 46             71.1     100.0       NaN
# 47             70.3  102896.0  105116.0
# 52              NaN       0.0       NaN
# 93              NaN       0.0       NaN
# 187             NaN       0.0       NaN
#
#                                         LocalName  \
# 0                                           Aruba
# 1                           Afganistan/Afqanestan
# 2                                          Angola
# 3                                        Anguilla
# 4                                      ShqipÃ«ria
# 5                                         Andorra
# 6                            Nederlandse Antillen
# 7             Al-Imarat al-Â´Arabiya al-Muttahida
# 8                                       Argentina
# 9                                        Hajastan
# 10                                  Amerika Samoa
# 11                                             Â–
# 12                   Terres australes franÃ§aises
# 13                            Antigua and Barbuda
# 14                                      Australia
# 15                                    Ã–sterreich
# 16                                    AzÃ¤rbaycan
# 17                               Burundi/Uburundi
# 18                               BelgiÃ«/Belgique
# 19                                         BÃ©nin
# 20                                   Burkina Faso
# 21                                     Bangladesh
# 22                                      Balgarija
# 24                                    The Bahamas
# 29                                        Bolivia
# 30                                         Brasil
# 34                                     BouvetÃ¸ya
# 35                                       Botswana
# 38                        Cocos (Keeling) Islands
# 40                                          Chile
# 46                               The Cook Islands
# 47                                       Colombia
# 52                               Christmas Island
# 93                     Heard and McDonald Islands
# 187  South Georgia and the South Sandwich Islands
#
#                                    GovernmentForm  \
# 0    Nonmetropolitan Territory of The Netherlands
# 1                                 Islamic Emirate
# 2                                        Republic
# 3                   Dependent Territory of the UK
# 4                                        Republic
# 5                    Parliamentary Coprincipality
# 6    Nonmetropolitan Territory of The Netherlands
# 7                              Emirate Federation
# 8                                Federal Republic
# 9                                        Republic
# 10                                   US Territory
# 11                               Co-administrated
# 12            Nonmetropolitan Territory of France
# 13                        Constitutional Monarchy
# 14            Constitutional Monarchy, Federation
# 15                               Federal Republic
# 16                               Federal Republic
# 17                                       Republic
# 18            Constitutional Monarchy, Federation
# 19                                       Republic
# 20                                       Republic
# 21                                       Republic
# 22                                       Republic
# 24                        Constitutional Monarchy
# 29                                       Republic
# 30                               Federal Republic
# 34                  Dependent Territory of Norway
# 35                                       Republic
# 38                         Territory of Australia
# 40                                       Republic
# 46       Nonmetropolitan Territory of New Zealand
# 47                                       Republic
# 52                         Territory of Australia
# 93                         Territory of Australia
# 187                 Dependent Territory of the UK
#
#                      HeadOfState  Capital Code2
# 0                        Beatrix    129.0    AW
# 1                  Mohammad Omar      1.0    AF
# 2       JosÃ© Eduardo dos Santos     56.0    AO
# 3                   Elisabeth II     62.0    AI
# 4                 Rexhep Mejdani     34.0    AL
# 5                            NaN     55.0    AD
# 6                        Beatrix     33.0    AN
# 7    Zayid bin Sultan al-Nahayan     65.0    AE
# 8            Fernando de la RÃºa     69.0    AR
# 9              Robert KotÂšarjan    126.0    AM
# 10                George W. Bush     54.0    AS
# 11                           NaN      NaN    AQ
# 12                Jacques Chirac      NaN    TF
# 13                  Elisabeth II     63.0    AG
# 14                  Elisabeth II    135.0    AU
# 15                Thomas Klestil   1523.0    AT
# 16               HeydÃ¤r Ã„liyev    144.0    AZ
# 17                 Pierre Buyoya    552.0    BI
# 18                     Albert II    179.0    BE
# 19             Mathieu KÃ©rÃ©kou    187.0    BJ
# 20              Blaise CompaorÃ©    549.0    BF
# 21             Shahabuddin Ahmad    150.0    BD
# 22                Petar Stojanov    539.0    BG
# 24                  Elisabeth II    148.0    BS
# 29          Hugo BÃ¡nzer SuÃ¡rez    194.0    BO
# 30     Fernando Henrique Cardoso    211.0    BR
# 34                      Harald V      NaN    BV
# 35               Festus G. Mogae    204.0    BW
# 38                  Elisabeth II   2317.0    CC
# 40         Ricardo Lagos Escobar    554.0    CL
# 46                  Elisabeth II    583.0    CK
# 47       AndrÃ©s Pastrana Arango   2257.0    CO
# 52                  Elisabeth II   1791.0    CX
# 93                  Elisabeth II      NaN    HM
# 187                 Elisabeth II      NaN    GS

# %%
gc.head(1) # 각각의 그룹에서 처음 row 1개씩
# Out:
#    Code            Name      Continent                     Region  \
# 0   ABW           Aruba  North America                  Caribbean
# 1   AFG     Afghanistan           Asia  Southern and Central Asia
# 2   AGO          Angola         Africa             Central Africa
# 4   ALB         Albania         Europe            Southern Europe
# 8   ARG       Argentina  South America              South America
# 10  ASM  American Samoa        Oceania                  Polynesia
# 11  ATA      Antarctica     Antarctica                 Antarctica
#
#     SurfaceArea  IndepYear  Population  LifeExpectancy       GNP    GNPOld  \
# 0         193.0        NaN      103000            78.4     828.0     793.0
# 1      652090.0     1919.0    22720000            45.9    5976.0       NaN
# 2     1246700.0     1975.0    12878000            38.3    6648.0    7984.0
# 4       28748.0     1912.0     3401200            71.6    3205.0    2500.0
# 8     2780400.0     1816.0    37032000            75.1  340238.0  323310.0
# 10        199.0        NaN       68000            75.1     334.0       NaN
# 11   13120000.0        NaN           0             NaN       0.0       NaN
#
#                 LocalName                                GovernmentForm  \
# 0                   Aruba  Nonmetropolitan Territory of The Netherlands
# 1   Afganistan/Afqanestan                               Islamic Emirate
# 2                  Angola                                      Republic
# 4              ShqipÃ«ria                                      Republic
# 8               Argentina                              Federal Republic
# 10          Amerika Samoa                                  US Territory
# 11                     Â–                              Co-administrated
#
#                  HeadOfState  Capital Code2
# 0                    Beatrix    129.0    AW
# 1              Mohammad Omar      1.0    AF
# 2   JosÃ© Eduardo dos Santos     56.0    AO
# 4             Rexhep Mejdani     34.0    AL
# 8        Fernando de la RÃºa     69.0    AR
# 10            George W. Bush     54.0    AS
# 11                       NaN      NaN    AQ

# %%
# 대륙별 인구가 가장 많은 국가 1개씩 뽑기
df.sort_values("Population", ascending=False).groupby("Continent").head(1)
# Out:
#     Code                Name      Continent                     Region  \
# 41   CHN               China           Asia               Eastern Asia
# 223  USA       United States  North America              North America
# 30   BRA              Brazil  South America              South America
# 181  RUS  Russian Federation         Europe             Eastern Europe
# 155  NGA             Nigeria         Africa             Western Africa
# 14   AUS           Australia        Oceania  Australia and New Zealand
# 11   ATA          Antarctica     Antarctica                 Antarctica
#
#      SurfaceArea  IndepYear  Population  LifeExpectancy        GNP     GNPOld  \
# 41     9572900.0    -1523.0  1277558000            71.4   982268.0   917719.0
# 223    9363520.0     1776.0   278357000            77.1  8510700.0  8110900.0
# 30     8547403.0     1822.0   170115000            62.9   776739.0   804108.0
# 181   17075400.0     1991.0   146934000            67.2   276608.0   442989.0
# 155     923768.0     1960.0   111506000            51.6    65707.0    58623.0
# 14     7741220.0     1901.0    18886000            79.8   351182.0   392911.0
# 11    13120000.0        NaN           0             NaN        0.0        NaN
#
#          LocalName                       GovernmentForm  \
# 41        Zhongquo                     People'sRepublic
# 223  United States                     Federal Republic
# 30          Brasil                     Federal Republic
# 181        Rossija                     Federal Republic
# 155        Nigeria                     Federal Republic
# 14       Australia  Constitutional Monarchy, Federation
# 11              Â–                     Co-administrated
#
#                    HeadOfState  Capital Code2
# 41                 Jiang Zemin   1891.0    CN
# 223             George W. Bush   3813.0    US
# 30   Fernando Henrique Cardoso    211.0    BR
# 181             Vladimir Putin   3580.0    RU
# 155          Olusegun Obasanjo   2754.0    NG
# 14                Elisabeth II    135.0    AU
# 11                         NaN      NaN    AQ

# %% [markdown]
# # 대륙별, 인구합계,인구평균, 면적합계
# - 대륙별
#     - 인구는 "합계","평균"
#     - 면적은 "합계 "

# %%
gc.agg("sum")
gc.agg(np.sum)
# Out:
#                SurfaceArea  IndepYear  Population  LifeExpectancy        GNP  \
# Continent
# Africa          30250377.0   100960.0   784475000          2996.6   580375.0
# Antarctica      13132101.0        0.0           0             0.0        0.0
# Asia            31881005.0    85001.0  3705025700          3439.5  7655392.0
# Europe          23049133.9    75271.0   730074600          3306.5  9498865.0
# North America   24214470.0    43783.0   482993000          2700.7  9688627.2
# Oceania          8564294.0    27542.0    30401150          1394.3   419774.7
# South America   17864926.0    22117.0   345780000           922.3  1511874.0
#
#                   GNPOld   Capital
# Continent
# Africa          553264.0  123255.0
# Antarctica           0.0       0.0
# Asia           8251969.0  103979.0
# Europe         9382001.0  102294.0
# North America  9288175.0   58934.0
# Oceania         469058.0   67448.0
# South America  1520641.0   24633.0

# %%
# 대륙별 '인구' 에 대해서만 sum 구하기
gc.agg('sum')['Population']
# Out:
# Continent
# Africa            784475000
# Antarctica                0
# Asia             3705025700
# Europe            730074600
# North America     482993000
# Oceania            30401150
# South America     345780000
# Name: Population, dtype: int64

# %%
# GroupBy 객체에 특정 column 만 뽑아낼수 있다!!
gc['Population'].agg('sum')  # 위와 동일한 결과!
# Out:
# Continent
# Africa            784475000
# Antarctica                0
# Asia             3705025700
# Europe            730074600
# North America     482993000
# Oceania            30401150
# South America     345780000
# Name: Population, dtype: int64

# %%
df.describe()
# Out:
#         SurfaceArea    IndepYear    Population  LifeExpectancy           GNP  \
# count  2.390000e+02   192.000000  2.390000e+02      222.000000  2.390000e+02
# mean   6.232481e+05  1847.260417  2.543410e+07       66.486036  1.228239e+05
# std    1.924140e+06   420.831370  1.093398e+08       11.519267  6.379976e+05
# min    4.000000e-01 -1523.000000  0.000000e+00       37.200000  0.000000e+00
# 25%    2.275000e+03  1906.750000  2.380000e+05       60.300000  6.400000e+02
# 50%    7.174000e+04  1960.000000  3.869000e+06       70.150000  4.787000e+03
# 75%    3.987545e+05  1974.000000  1.493550e+07       75.500000  2.994450e+04
# max    1.707540e+07  1994.000000  1.277558e+09       83.500000  8.510700e+06
#
#              GNPOld      Capital
# count  1.780000e+02   232.000000
# mean   1.655343e+05  2071.306034
# std    7.204689e+05  1184.095609
# min    1.570000e+02     1.000000
# 25%    2.187000e+03   915.750000
# 50%    8.421000e+03  2449.500000
# 75%    7.114550e+04  3065.250000
# max    8.110900e+06  4074.000000

# %%
# describe() 연산
gc.agg("describe")  # describe 가 numpy 에 있는 기술통계량 집계 연산들 (count, mean, std, min .... ) 을 다 해준다!!
                    #그룹별로 전체적인 데이터 모양새를 보고 싶을때 활용하면 좋다
# Out:
#               SurfaceArea                                                  \
#                     count          mean           std      min        25%
# Continent
# Africa               58.0  5.215582e+05  6.288632e+05     78.0   28627.00
# Antarctica            5.0  2.626420e+06  5.866090e+06     59.0     359.00
# Asia                 51.0  6.251177e+05  1.466192e+06     18.0   25428.00
# Europe               46.0  5.010681e+05  2.503180e+06      0.4   29190.50
# North America        37.0  6.544451e+05  2.235040e+06     53.0     347.00
# Oceania              28.0  3.058676e+05  1.460543e+06     12.0     113.50
# South America        14.0  1.276066e+06  2.217233e+06  12173.0  185004.25
#
#                                                 IndepYear               ...  \
#                     50%         75%         max     count         mean  ...
# Continent                                                               ...
# Africa         266834.0   818616.50   2505813.0      53.0  1904.905660  ...
# Antarctica       3903.0     7780.00  13120000.0       0.0          NaN  ...
# Asia           147181.0   500607.50   9572900.0      47.0  1808.531915  ...
# Europe          64945.0   230693.25  17075400.0      43.0  1750.488372  ...
# North America    1705.0    51100.00   9970610.0      23.0  1903.608696  ...
# Oceania           461.5     6047.25   7741220.0      14.0  1967.285714  ...
# South America  581689.0  1128830.75   8547403.0      12.0  1843.083333  ...
#
#                   GNPOld            Capital                                  \
#                      75%        max   count         mean          std   min
# Continent
# Africa           7835.00   129092.0    57.0  2162.368421  1089.668620  35.0
# Antarctica           NaN        NaN     0.0          NaN          NaN   NaN
# Asia           146171.00  4192638.0    51.0  2038.803922  1133.096342   1.0
# Europe         231804.75  2102826.0    46.0  2223.782609  1169.124761   5.0
# North America   15076.00  8110900.0    37.0  1592.810811  1297.572538  33.0
# Oceania          5283.25   392911.0    27.0  2498.074074  1070.362840  54.0
# South America   92604.50   804108.0    14.0  1759.500000  1385.014954  69.0
#
#
#                   25%     50%     75%     max
# Continent
# Africa          926.0  2462.0  3063.0  4068.0
# Antarctica        NaN     NaN     NaN     NaN
# Asia           1237.0  2331.0  2902.0  4074.0
# Europe         1447.5  2472.0  3199.5  3791.0
# North America   553.0   929.0  2882.0  4067.0
# Oceania        2286.5  2881.0  3251.0  3537.0
# South America   564.0  1592.5  2983.0  3539.0
#
# [7 rows x 56 columns]

# %%
# agg() 에 list 적용가능
gc.agg(['sum', 'mean', 'max']) # 각각의 column 에 대해서 sum 연산, mean 연산, max 연산 수행
# Out:
#               SurfaceArea                           IndepYear               \
#                       sum          mean         max       sum         mean
# Continent
# Africa         30250377.0  5.215582e+05   2505813.0  100960.0  1904.905660
# Antarctica     13132101.0  2.626420e+06  13120000.0       0.0          NaN
# Asia           31881005.0  6.251177e+05   9572900.0   85001.0  1808.531915
# Europe         23049133.9  5.010681e+05  17075400.0   75271.0  1750.488372
# North America  24214470.0  6.544451e+05   9970610.0   43783.0  1903.608696
# Oceania         8564294.0  3.058676e+05   7741220.0   27542.0  1967.285714
# South America  17864926.0  1.276066e+06   8547403.0   22117.0  1843.083333
#
#                        Population                           LifeExpectancy  \
#                   max         sum          mean         max            sum
# Continent
# Africa         1993.0   784475000  1.352543e+07   111506000         2996.6
# Antarctica        NaN           0  0.000000e+00           0            0.0
# Asia           1991.0  3705025700  7.264756e+07  1277558000         3439.5
# Europe         1993.0   730074600  1.587119e+07   146934000         3306.5
# North America  1983.0   482993000  1.305386e+07   278357000         2700.7
# Oceania        1994.0    30401150  1.085755e+06    18886000         1394.3
# South America  1975.0   345780000  2.469857e+07   170115000          922.3
#
#                ...              GNP                               GNPOld  \
#                ...   max        sum           mean        max        sum
# Continent      ...
# Africa         ...  76.8   580375.0   10006.465517   116729.0   553264.0
# Antarctica     ...   NaN        0.0       0.000000        0.0        0.0
# Asia           ...  81.6  7655392.0  150105.725490  3787042.0  8251969.0
# Europe         ...  83.5  9498865.0  206497.065217  2133367.0  9382001.0
# North America  ...  79.4  9688627.2  261854.789189  8510700.0  9288175.0
# Oceania        ...  79.8   419774.7   14991.953571   351182.0   469058.0
# South America  ...  76.1  1511874.0  107991.000000   776739.0  1520641.0
#
#                                           Capital
#                         mean        max       sum         mean     max
# Continent
# Africa          11065.280000   129092.0  123255.0  2162.368421  4068.0
# Antarctica               NaN        NaN       0.0          NaN     NaN
# Asia           183377.088889  4192638.0  103979.0  2038.803922  4074.0
# Europe         260611.138889  2102826.0  102294.0  2223.782609  3791.0
# North America  371527.000000  8110900.0   58934.0  1592.810811  4067.0
# Oceania         46905.800000   392911.0   67448.0  2498.074074  3537.0
# South America  126720.083333   804108.0   24633.0  1759.500000  3539.0
#
# [7 rows x 21 columns]

# %%
# 대륙별, 
# 인구는 "합계","평균"을
# 면적은 "합계 " 만.  

# df.groupby("Continent").agg({})         agg() 에 dict 적용하기
# { "칼럼명" : "연산" }  <- 요런 형식의 dict 를 적용한다.


gc.agg({
    "Population" : ['sum', 'mean'],
    "SurfaceArea" : ["sum"]
})
# Out:
#                Population               SurfaceArea
#                       sum          mean         sum
# Continent
# Africa          784475000  1.352543e+07  30250377.0
# Antarctica              0  0.000000e+00  13132101.0
# Asia           3705025700  7.264756e+07  31881005.0
# Europe          730074600  1.587119e+07  23049133.9
# North America   482993000  1.305386e+07  24214470.0
# Oceania          30401150  1.085755e+06   8564294.0
# South America   345780000  2.469857e+07  17864926.0
