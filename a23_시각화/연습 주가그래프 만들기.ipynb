# %%
# 코스피지수 (종목명 'KS11') 의 2021.1.1 부터 2021.4.30 의 주가 그래프를 
# 다음과 같이 그려보세요
# ※ 주가는 종가 (Close) 사용

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
import platform

try : 
    if platform.system() == 'Windows':
    # 윈도우인 경우
        font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
        rc('font', family=font_name)
    else:    
    # Mac 인 경우
        rc('font', family='AppleGothic')
except : 
    pass
matplotlib.rcParams['axes.unicode_minus'] = False  

import FinanceDataReader as fdr
from datetime import datetime

# %%
df = fdr.DataReader('KS11', datetime(2021, 1, 1), datetime(2021, 4, 30))
df
# Out:
#               Close     Open     High      Low        Volume  Change
# Date
# 2021-01-04  2944.45  2874.50  2946.54  2869.11  1.030000e+09  0.0247
# 2021-01-05  2990.57  2943.67  2990.57  2921.84  1.520000e+09  0.0157
# 2021-01-06  2968.21  2993.34  3027.16  2961.37  1.790000e+09 -0.0075
# 2021-01-07  3031.68  2980.75  3055.28  2980.75  1.520000e+09  0.0214
# 2021-01-08  3152.18  3040.11  3161.11  3040.11  1.300000e+09  0.0397
# ...             ...      ...      ...      ...           ...     ...
# 2021-04-26  3217.53  3191.34  3217.53  3191.34  1.300000e+09  0.0099
# 2021-04-27  3215.42  3218.30  3223.05  3203.25  1.530000e+09 -0.0007
# 2021-04-28  3181.47  3217.21  3219.69  3176.55  1.410000e+09 -0.0106
# 2021-04-29  3174.07  3184.75  3200.41  3161.06  1.220000e+09 -0.0023
# 2021-04-30  3147.86  3176.43  3179.43  3143.38  1.360000e+09 -0.0083
#
# [82 rows x 6 columns]

# %%
df.index
# Out:
# DatetimeIndex(['2021-01-04', '2021-01-05', '2021-01-06', '2021-01-07',
#                '2021-01-08', '2021-01-11', '2021-01-12', '2021-01-13',
#                '2021-01-14', '2021-01-15', '2021-01-18', '2021-01-19',
#                '2021-01-20', '2021-01-21', '2021-01-22', '2021-01-25',
#                '2021-01-26', '2021-01-27', '2021-01-28', '2021-01-29',
#                '2021-02-01', '2021-02-02', '2021-02-03', '2021-02-04',
#                '2021-02-05', '2021-02-08', '2021-02-09', '2021-02-10',
#                '2021-02-15', '2021-02-16', '2021-02-17', '2021-02-18',
#                '2021-02-19', '2021-02-22', '2021-02-23', '2021-02-24',
#                '2021-02-25', '2021-02-26', '2021-03-02', '2021-03-03',
#                '2021-03-04', '2021-03-05', '2021-03-08', '2021-03-09',
#                '2021-03-10', '2021-03-11', '2021-03-12', '2021-03-15',
#                '2021-03-16', '2021-03-17', '2021-03-18', '2021-03-19',
# ...

# %%
df['Close']
# Out:
# Date
# 2021-01-04    2944.45
# 2021-01-05    2990.57
# 2021-01-06    2968.21
# 2021-01-07    3031.68
# 2021-01-08    3152.18
#                ...
# 2021-04-26    3217.53
# 2021-04-27    3215.42
# 2021-04-28    3181.47
# 2021-04-29    3174.07
# 2021-04-30    3147.86
# Name: Close, Length: 82, dtype: float64

# %%
df = fdr.DataReader('KS11', datetime(2021, 1, 1), datetime(2021, 4, 30))
x_val = df.index
y_val = df['Close']

fig = plt.figure(figsize=(16,4))
ax = fig.add_subplot(111)

ax.set_xticklabels(df.index, rotation=50, fontsize="small")

ax.set_title('2021 KOSPI index')
ax.set_xlabel('date')
plt.plot(y_val, "red")
# Out:
# <ipython-input-16-c20c527376ee>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df.index, rotation=50, fontsize="small")
