# %% [markdown]
# # 연습 : 영화 평점
# 파일 : rating.csv

# %% [markdown]
# ## 1. 파일 읽어 들이기

# %%
import numpy as np

# %%
# rating.csv 파일의 내용을 확인하고
# numpy 의 array 로 읽어 들어와 arr_rating 이라는 변수에 담습니다.
# 읽어온뒤 내용도 확인합니다

# userid(A), moiveid(B), rating(C) 순

# %%
filepath = r'C:\DevRoot\DataSet\rating.csv'

# %%
with open(filepath, "r", encoding='utf-8') as f:
    data = f.read()
    arr_rating = np.array([data])

arr_rating
# Out:
# array(['1,2,3.5\n1,29,3.5\n1,32,3.5\n1,47,3.5\n1,50,3.5\n1,112,3.5\n1,151,4.0\n1,223,4.0\n1,253,4.0\n1,260,4.0\n1,293,4.0\n1,296,4.0\n1,318,4.0\n1,337,3.5\n1,367,3.5\n1,541,4.0\n1,589,3.5\n1,593,3.5\n1,653,3.0\n1,919,3.5\n1,924,3.5\n1,1009,3.5\n1,1036,4.0\n1,1079,4.0\n1,1080,3.5\n1,1089,3.5\n1,1090,4.0\n1,1097,4.0\n1,1136,3.5\n1,1193,3.5\n1,1196,4.5\n1,1198,4.5\n1,1200,4.0\n1,1201,3.0\n1,1208,3.5\n1,1214,4.0\n1,1215,4.0\n1,1217,3.5\n1,1219,4.0\n1,1222,3.5\n1,1240,4.0\n1,1243,3.0\n1,1246,3.5\n1,1249,4.0\n1,1258,4.0\n1,1259,4.0\n1,1261,3.5\n1,1262,3.5\n1,1266,4.0\n1,1278,4.0\n1,1291,3.5\n1,1304,3.0\n1,1321,4.0\n1,1333,4.0\n1,1348,3.5\n1,1350,3.5\n1,1358,4.0\n1,1370,3.0\n1,1374,4.0\n1,1387,4.0\n1,1525,3.0\n1,1584,3.5\n1,1750,3.5\n1,1848,3.5\n1,1920,3.5\n1,1967,4.0\n1,1994,3.5\n1,1997,3.5\n1,2021,4.0\n1,2100,4.0\n1,2118,4.0\n1,2138,4.0\n1,2140,4.0\n1,2143,4.0\n1,2173,4.0\n1,2174,4.0\n1,2193,4.0\n1,2194,3.5\n1,2253,3.5\n1,2288,4.0\n1,2291,4.0\n1,2542,4.0\n1,2628,4.0\n1,2644,3.5\n1,2648,3.5\n1,2664,3.5\n1,2683,3.5\n1,2692,3.5\n1,2716,3.5\n1,2761,3.0\n1,2762,4.0\n1,2804,3.5\n1,2872,4.0\n1,2918,3.5\n1,2944,4.0\n1,2947,3.5\n1,2959,4.0\n1,2968,4.0\n1,3000,3.5\n1,3030,3.0\n1,3037,3.5\n1,3081,4.0\n1,3153,4.0\n1,3265,3.5\n1,3438,3.5\n1,3476,3.5\n1,3479,4.0\n1,3489,4.0\n1,3499,4.0\n1,3889,4.0\n1,3932,3.0\n1,3996,4.0\n1,3997,3.5\n1,4011,4.0\n1,4027,4.0\n1,4105,3.5\n1,4128,4.0\n1,4133,3.0\n1,4226,3.5\n1,4306,4.0\n1,4446,3.5\n1,4467,4.0\n1,4571,4.0\n1,4720,3.5\n1,4754,4.0\n1,4878,3.5\n1,4896,4.0\n1,4911,4.0\n1,4915,3.0\n1,4941,3.5\n1,4980,3.5\n1,4993,5.0\n1,5026,4.0\n1,5039,4.0\n1,5040,3.0\n1,5146,3.5\n1,5171,4.0\n1,5540,4.0\n1,5679,3.5\n1,5797,4.0\n1,5816,4.0\n1,5898,3.5\n1,5952,5.0\n1,5999,3.5\n1,6093,4.0\n1,6242,3.5\n1,6333,4.0\n1,6502,3.5\n1,6539,4.0\n1,6754,4.0\n1,6755,3.5\n1,6774,4.0\n1,6807,3.5\n1,6834,3.5\n1,6888,3.0\n1,7001,3.5\n1,7045,3.5\n1,7046,4.0\n1,7153,5.0\n1,7164,3.5\n1,7247,3.5\n1,7387,3.5\n1,7389,4.0\n1,7438,4.0\n1,7449,3.5\n1,7454,4.0\n1,7482,3.0\n1,7757,4.0\n1,8368,4.0\n1,8482,3.5\n1,8507,5.0\n1,8636,4.5\n1,8690,3.5\n1,8961,4.0\n1,31696,4.0\n2,3,4.0\n2,62,5.0\n2,70,5.0\n2,110,4.0\n2,242,3.0\n2,260,5.0\n2,266,5.0\n2,469,3.0\n2,480,5.0\n2,541,5.0\n2,589,5.0\n2,891,2.0\n2,908,4.0\n2,924,5.0\n2,1121,3.0\n2,1196,5.0\n2,1210,5.0\n2,1214,5.0\n2,1249,5.0\n2,1259,5.0\n2,1270,5.0\n2,1327,5.0\n2,1356,5.0\n2,1544,5.0\n2,1580,4.0\n2,1673,4.0\n2,1748,5.0\n2,1965,3.0\n2,1969,2.0\n2,1970,2.0\n2,1971,2.0\n2,1972,2.0\n2,1973,3.0\n2,1974,5.0\n2,1986,2.0\n2,2291,2.0\n2,2454,4.0\n2,2455,4.0\n2,2791,2.0\n2,2858,3.0\n2,2948,5.0\n2,2951,4.0\n2,3150,4.0\n2,3159,3.0\n2,3173,4.0\n2,3450,5.0\n2,3513,5.0\n2,3534,3.0\n2,3555,4.0\n2,3565,3.0\n2,3703,4.0\n2,3753,4.0\n2,3917,4.0\n2,3918,3.0\n2,3923,4.0\n2,3926,4.0\n2,3927,5.0\n2,3928,5.0\n2,3930,5.0\n2,3937,4.0\n2,3959,5.0\n3,1,4.0\n3,24,3.0\n3,32,4.0\n3,50,5.0\n3,160,3.0\n3,173,2.0\n3,175,5.0\n3,196,3.0\n3,223,5.0\n3,260,5.0\n3,316,5.0\n3,318,5.0\n3,329,5.0\n3,337,3.0\n3,440,3.0\n3,442,3.0\n3,457,5.0\n3,480,5.0\n3,490,5.0\n3,512,2.0\n3,541,5.0\n3,589,4.0\n3,593,5.0\n3,610,4.0\n3,718,3.0\n3,780,3.0\n3,788,4.0\n3,858,5.0\n3,904,5.0\n3,905,3.0\n3,919,4.0\n3,924,5.0\n3,953,5.0\n3,968,3.0\n3,1037,3.0\n3,1060,5.0\n3,1073,5.0\n3,1077,4.0\n3,1079,4.0\n3,1084,5.0\n3,1089,5.0\n3,1094,4.0\n3,1097,5.0\n3,1103,4.0\n3,1125,4.0\n3,1127,3.0\n3,1129,5.0\n3,1179,3.0\n3,1188,2.0\n3,1193,4.0\n3,1196,5.0\n3,1197,5.0\n3,1198,5.0\n3,1199,4.0\n3,1200,4.0\n3,1206,5.0\n3,1208,5.0\n3,1210,5.0\n3,1213,5.0\n3,1214,5.0\n3,1215,4.0\n3,1219,4.0\n3,1220,5.0\n3,1221,5.0\n3,1222,5.0\n3,1225,3.0\n3,1228,3.0\n3,1230,5.0\n3,1240,5.0\n3,1242,5.0\n3,1247,5.0\n3,1257,5.0\n3,1258,5.0\n3,1259,5.0\n3,1261,5.0\n3,1266,5.0\n3,1270,5.0\n3,1272,4.0\n3,1276,5.0\n3,1278,5.0\n3,1288,2.0\n3,1304,5.0\n3,1307,4.0\n3,1321,5.0\n3,1330,3.0\n3,1333,4.0\n3,1345,4.0\n3,1356,5.0\n3,1372,3.0\n3,1373,4.0\n3,1374,5.0\n3,1375,5.0\n3,1376,4.0\n3,1396,3.0\n3,1544,4.0\n3,1584,4.0\n3,1603,4.0\n3,1653,4.0\n3,1674,4.0\n3,1676,5.0\n3,1721,4.0\n3,1762,4.0\n3,1779,3.0\n3,1810, ...
#       dtype='<U1267727')

# %%
# x.shape, x.ndim, x.dtype, x.size, len(x)
# Out:
# array([], dtype=float64)

# %% [markdown]
# ## 2.데이터 탐색하기

# %%
# arr_rating 의 
# A) 데이터 개수, 차원 정보등을 확인해봅니다.
# B)  0 ~ 4번째 row만 출력해봅니다
# C)  0번째 칼럼(열)만 출력

# D) 3번째 칼럼(영화평점)의 최소,최대값을 확인해봅시다

# %%
# arr_rating[:'\n']

# %%
arr_rating.shape, arr_rating.ndim, arr_rating.dtype, arr_rating.size, len(arr_rating)
# Out:
# ((1,), 1, dtype('<U1267727'), 1, 1)

# %% [markdown]
# ## 3. 영화의 개수 구하기

# %%
# 평점이 매겨진 영화의 개수를 구해보세요

# %% [markdown]
# ## 4. 1번 유저에 대한 모든 평점 정보 구하기

# %%
# 1번 유저의 '평점 개수' 와 '평점 평균' 을 구하세요

# %% [markdown]
# ## 5. 각 유저별 정보 구하기

# %%
# 각 유저별
# 유저 아이디, 평점회수, 평점 평균
# 아래와 같이 list 로 출력

"""
[[1, 175, 3.742857142857143],
 [2, 61, 4.0],
 [3, 187, 4.122994652406417],
 [4, 28, 3.5714285714285716],
 [5, 66, 4.2727272727272725],
 [6, 24, 3.75],
 ...
 ...
"""
None
